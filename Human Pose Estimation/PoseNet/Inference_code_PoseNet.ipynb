# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !python --version
# Out:
# Python 3.7.12

# %%
# !pip install requests opencv-python==3.4.5.20
# Out:
# ...
#      |████████████████████████████████| 25.4 MB 15 kB/s
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
# !pip3 install torch==1.2.0+cu92 torchvision==0.4.0+cu92 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 663.1 MB 1.7 kB/s
# ...
#      |████████████████████████████████| 8.8 MB 28.5 MB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.0+cu102
#     Uninstalling torch-1.9.0+cu102:
#       Successfully uninstalled torch-1.9.0+cu102
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.10.0+cu102
#     Uninstalling torchvision-0.10.0+cu102:
#       Successfully uninstalled torchvision-0.10.0+cu102
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.10.0 requires torch==1.9.0, but you have torch 1.2.0+cu92 which is incompatible.
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 1.2.0+cu92

# %%
# !git clone https://github.com/rwightman/posenet-pytorch.git
# Out:
# Cloning into 'posenet-pytorch'...
# remote: Enumerating objects: 115, done.
# remote: Total 115 (delta 0), reused 0 (delta 0), pack-reused 115
# Receiving objects: 100% (115/115), 34.73 KiB | 987.00 KiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
# !python /content/posenet-pytorch/image_demo.py --model 101 --image_dir /content/posenet-pytorch/images --output_dir /content/posenet-pytorch/output
# Out:
# Cannot find models file ./_models/mobilenet_v1_101.pth, converting from tfjs...
# Weights for checkpoint mobilenet_v1_101 are not downloaded. Downloading to /tmp/_posenet_weights ...
# ...
#
# Results for image: /content/posenet-pytorch/images/img004.jpg
# Pose #0, score = 0.605169
# Keypoint nose, score = 0.999280, coord = [860.14971742 544.8829533 ]
# Keypoint leftEye, score = 0.972452, coord = [848.00405244 557.34368259]
# Keypoint rightEye, score = 0.996458, coord = [845.78169972 535.12183994]
# Keypoint leftEar, score = 0.669897, coord = [846.76273555 576.45823387]
# Keypoint rightEar, score = 0.464413, coord = [847.32640359 523.78003678]
# Keypoint leftShoulder, score = 0.909665, coord = [897.20650033 590.28407667]
# Keypoint rightShoulder, score = 0.989489, coord = [894.80031119 504.0917783 ]
# Keypoint leftElbow, score = 0.393243, coord = [964.05627693 618.24658133]
# Keypoint rightElbow, score = 0.485237, coord = [971.96948378 470.20001944]
# ...

# %%
import os
fi = os.listdir('/content/posenet-pytorch/images')
print(len(fi))
# Out:
# 891

# %%
for i in os.listdir('/content/posenet-pytorch/images'):
  os.remove(os.path.join('/content/posenet-pytorch/images', i))

# %%
fi = os.listdir('/content/posenet-pytorch/images')
print(len(fi))
# Out:
# 910

# %%
fo = os.listdir('/content/posenet-pytorch/output')
print(len(fo))
# Out:
# 911

# %%
for i in range(len(fo)-1):
  if fo[i] == fo[i+1]: 
    print(fo[i])

# %%
fi = sorted(fi)
fo = sorted(fo)

# %%
# !cp -av '/content/posenet-pytorch/json' '/content/drive/MyDrive/AIP391/Human_Pose_Estimation/PoseNet'
# Out:
# '/content/posenet-pytorch/json' -> '/content/drive/MyDrive/AIP391/Human_Pose_Estimation/PoseNet/json'
# '/content/posenet-pytorch/json/result.json' -> '/content/drive/MyDrive/AIP391/Human_Pose_Estimation/PoseNet/json/result.json'

# %%
# !cp -av '/content/posenet-pytorch/output' '/content/drive/MyDrive/AIP391/Human_Pose_Estimation/PoseNet/test_high_quality'
# Out:
# '/content/posenet-pytorch/output' -> '/content/drive/MyDrive/AIP391/Human_Pose_Estimation/PoseNet/test_high_quality/output'
# '/content/posenet-pytorch/output/img004.jpg' -> '/content/drive/MyDrive/AIP391/Human_Pose_Estimation/PoseNet/test_high_quality/output/img004.jpg'
# '/content/posenet-pytorch/output/img008.jpg' -> '/content/drive/MyDrive/AIP391/Human_Pose_Estimation/PoseNet/test_high_quality/output/img008.jpg'
# '/content/posenet-pytorch/output/img006.jpg' -> '/content/drive/MyDrive/AIP391/Human_Pose_Estimation/PoseNet/test_high_quality/output/img006.jpg'
# '/content/posenet-pytorch/output/img014.jpg' -> '/content/drive/MyDrive/AIP391/Human_Pose_Estimation/PoseNet/test_high_quality/output/img014.jpg'
# '/content/posenet-pytorch/output/img009.jpg' -> '/content/drive/MyDrive/AIP391/Human_Pose_Estimation/PoseNet/test_high_quality/output/img009.jpg'
# ...

# %%
fopen = os.listdir('/content/drive/MyDrive/AIP391/Human_Pose_Estimation/AlphaPose/test/vis')
print(len(fopen))
# Out:
# 913

# %%
import json

# %%
with open('/content/posenet-pytorch/json/result.json') as fr: 
  data = json.load(fr)
fr.close()

# %%
data
# Out:
# [{'image': '/content/posenet-pytorch/images/im0002.jpg',
#   'keypoints': [[41.1124706120071, 81.5958206653595],
#    [38.80603290963049, 83.60345268249512],
#    [38.23758800042108, 79.28416913747787],
#    [38.0965136789905, 88.62621784210205],
#    [37.22443834734704, 72.99568033218384],
#    [53.55483106257384, 94.4195545911789],
#    [50.67266639711943, 66.38898181915283],
#    [68.14336319661511, 112.01072097197175],
#    [75.26728891955756, 51.81242609024048],
#    [93.67006490144087, 111.69977095723152],
#    [74.08202009250462, 61.34183096885681],
#    [99.6115877520235, 86.1432318687439],
#    [93.77184654888093, 64.2277669608593],
#    [120.34090682014899, 85.23109436035156],
#    [134.154536054542, 52.09522342681885],
#    [155.40374578466069, 87.62973165512085],
#    [166.77114522271822, 25.78697967529297]],
#   'pose': 0,
#   'scores': 0.8879658667480245},
#  {'image': '/content/posenet-pytorch/images/im0008.jpg',
# ...

# %%
print(len(data))
# Out:
# 1237

# %%
data_new = data.copy()
while
# Out:
#   File "<ipython-input-46-a7501f6afe3d>", line 2
#     for i in range(len(data)-1):
#                                  ^
# SyntaxError: unexpected EOF while parsing
