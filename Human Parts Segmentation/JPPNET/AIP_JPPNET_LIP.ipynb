# %%
# !python3 --version
# Out:
# Python 3.7.12

# %%
# !git clone https://github.com/minar09/LIP-JPPNet-TensorFlow.git
# Out:
# Cloning into 'LIP-JPPNet-TensorFlow'...
# remote: Enumerating objects: 207, done.
# remote: Total 207 (delta 0), reused 0 (delta 0), pack-reused 207
# Receiving objects: 100% (207/207), 2.66 MiB | 15.46 MiB/s, done.
# Resolving deltas: 100% (109/109), done.

# %%
#Truy cập vào folder Self-Correction-Human-Parsing (project mình đang làm việc với nó)
# %cd LIP-JPPNet-TensorFlow

#Tạo folders
# !mkdir checkpoint
# !mkdir inputs 
# !mkdir outputs
# Out:
# /content/LIP-JPPNet-TensorFlow

# %%
import gdown

url = 'https://drive.google.com/u/1/uc?id=1BFVXgeln-bek8TCbRjN6utPAgRE0LJZg&export=download'
output = '20150428_collected_images.zip'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/u/1/uc?id=1BFVXgeln-bek8TCbRjN6utPAgRE0LJZg&export=download
# To: /content/LIP-JPPNet-TensorFlow/20150428_collected_images.zip
# 913MB [00:04, 185MB/s]
# '20150428_collected_images.zip'

# %%
# !unzip "/content/LIP-JPPNet-TensorFlow/20150428_collected_images.zip" -d "/content/LIP-JPPNet-TensorFlow/checkpoint"
# Out:
# Archive:  /content/LIP-JPPNet-TensorFlow/20150428_collected_images.zip
#    creating: /content/LIP-JPPNet-TensorFlow/checkpoint/JPPNet-s2/
#   inflating: /content/LIP-JPPNet-TensorFlow/checkpoint/JPPNet-s2/checkpoint
#   inflating: /content/LIP-JPPNet-TensorFlow/checkpoint/JPPNet-s2/model.ckpt-205632.data-00000-of-00001
#   inflating: /content/LIP-JPPNet-TensorFlow/checkpoint/JPPNet-s2/model.ckpt-205632.index
#   inflating: /content/LIP-JPPNet-TensorFlow/checkpoint/JPPNet-s2/model.ckpt-205632.meta

# %%
################### INPUT IMAGE

# %%
#Truy cập vào folders inputs 
# %cd inputs 

#tải ảnh cần parse từ máy tính vào folder inputs
from google.colab import files 
uploaded = files.upload()

#thoát khỏi folder inputs, quay trở lại ra folders lớn
# %cd ..

# %%
# !gdown https://drive.google.com/uc?id=1B9A9UCJYMwTL4oBEo4RZfbMZMaZhKJaz
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1B9A9UCJYMwTL4oBEo4RZfbMZMaZhKJaz
# To: /content/LIP-JPPNet-TensorFlow/instance-level-human-parsing.zip
# 2.91GB [00:39, 22.4MB/s]

# %%
# !unzip -q instance-level-human-parsing.zip

# %%
import glob, os, shutil

source_dir = '/content/LIP-JPPNet-TensorFlow/instance-level_human_parsing/instance-level_human_parsing/Validation/Images' #Path where your files are at the moment
dst = '/content/LIP-JPPNet-TensorFlow/inputs/images' #Path you want to move your files to

count = 0
files = glob.iglob(os.path.join(source_dir, "*.jpg"))

for file in sorted(files):
  shutil.copy(file, dst)
  count += 1
  if count == 30:
    break

# %%
############# INSTALL LIBRARY AND RUN PROGRAM

# %%
# !pip install tensorflow==1.13.2

# %%
# !python3 evaluate_parsing_JPPNet-s2.py

# %%
# !python3 evaluate_pose_JPPNet-s2.py
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
########### CHUYEN FILE SANG FOLDER KHAC

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob, os, shutil

source_dir = '/content/LIP-JPPNet-TensorFlow/inputs/images' #Path where your files are at the moment
dst = '/content/drive/MyDrive/TEST_DATASETS_IoU/O_IMAGES' #Path you want to move your files to

count = 0
files = glob.iglob(os.path.join(source_dir, "*.jpg"))

for file in sorted(files):
  shutil.copy(file, dst)
  count += 1
  if count == 30:
    break
